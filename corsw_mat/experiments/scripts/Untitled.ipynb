# %%
# %cd /root/corsw_mat/experiments/scripts/
# Out:
# /root/corsw_mat/experiments/scripts

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py  --epho 500 --ntry 5 --lr_cov 5 --lr_cor 5 --lr_mix 0.5 --power 0.25 --distance lsm --task session --use_cov_net 1 --use_cor_net 1
# Out:
# ...
# NTRY Round 1/5, Seed: 2473
# ...
#
# [Seed 1/5, Exp 1/5] Running:
#   lr_cov=5.0e+00, lr_cor=5.0e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=0
# Training (lr_cov=5.0e+00, lr_cor=5.0e+00, lr_mix=5.0e-01, power=0.25, subject=1, seed=2473): 100%|██████████| 500/500 [00:05<00:00, 93.18it/s, loss = 0.000, lambda1=0.468, lambda2=0.532]
#   Results: align=0.854, no_align=0.833, time=6.1s
#
# [Seed 1/5, Exp 2/5] Running:
#   lr_cov=5.0e+00, lr_cor=5.0e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=3, target=0
# Training (lr_cov=5.0e+00, lr_cor=5.0e+00, lr_mix=5.0e-01, power=0.25, subject=3, seed=2473): 100%|██████████| 500/500 [00:05<00:00, 98.20it/s, loss = 0.000, lambda1=0.454, lambda2=0.546]
#   Results: align=0.868, no_align=0.799, time=5.1s
#
# [Seed 1/5, Exp 3/5] Running:
#   lr_cov=5.0e+00, lr_cor=5.0e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=7, target=0
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py  --epho 500 --ntry 5 --lr_cov 5 --lr_cor 5 --lr_mix 0.5 --power 0.25 --distance olm --task session --use_cov_net 1 --use_cor_net 1
# Out:
# ...
# NTRY Round 1/5, Seed: 2473
# ...
#
# [Seed 1/5, Exp 1/5] Running:
#   lr_cov=5.0e+00, lr_cor=5.0e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=0
# Training (lr_cov=5.0e+00, lr_cor=5.0e+00, lr_mix=5.0e-01, power=0.25, subject=1, seed=2473): 100%|██████████| 500/500 [00:05<00:00, 93.15it/s, loss = 0.000, lambda1=0.479, lambda2=0.521]
#   Results: align=0.847, no_align=0.847, time=6.1s
#
# [Seed 1/5, Exp 2/5] Running:
#   lr_cov=5.0e+00, lr_cor=5.0e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=3, target=0
# Training (lr_cov=5.0e+00, lr_cor=5.0e+00, lr_mix=5.0e-01, power=0.25, subject=3, seed=2473): 100%|██████████| 500/500 [00:05<00:00, 93.66it/s, loss = 0.000, lambda1=0.472, lambda2=0.528]
#   Results: align=0.850, no_align=0.806, time=5.3s
#
# [Seed 1/5, Exp 3/5] Running:
#   lr_cov=5.0e+00, lr_cor=5.0e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=7, target=0
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py  --epho 500 --ntry 5 --lr_cov 5 --lr_cor 5 --lr_mix 0.5 --power 0.25 --distance ecm --task session --use_cov_net 1 --use_cor_net 1
# Out:
# ...
# NTRY Round 1/5, Seed: 2473
# ...
#
# [Seed 1/5, Exp 1/5] Running:
#   lr_cov=5.0e+00, lr_cor=5.0e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=0
# Training (lr_cov=5.0e+00, lr_cor=5.0e+00, lr_mix=5.0e-01, power=0.25, subject=1, seed=2473): 100%|██████████| 500/500 [00:05<00:00, 93.17it/s, loss = 0.000, lambda1=0.479, lambda2=0.521]
#   Results: align=0.854, no_align=0.840, time=5.4s
#
# [Seed 1/5, Exp 2/5] Running:
#   lr_cov=5.0e+00, lr_cor=5.0e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=3, target=0
# Training (lr_cov=5.0e+00, lr_cor=5.0e+00, lr_mix=5.0e-01, power=0.25, subject=3, seed=2473): 100%|██████████| 500/500 [00:05<00:00, 94.96it/s, loss = 0.000, lambda1=0.472, lambda2=0.528]
#   Results: align=0.886, no_align=0.806, time=5.3s
#
# [Seed 1/5, Exp 3/5] Running:
#   lr_cov=5.0e+00, lr_cor=5.0e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=7, target=0
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py  --epho 500 --ntry 5 --lr_cov 5 --lr_cor 5 --lr_mix 0.5 --power 0.25 --distance lecm --task session --use_cov_net 1 --use_cor_net 1
# Out:
# ...
# NTRY Round 1/5, Seed: 2473
# ...
#
# [Seed 1/5, Exp 1/5] Running:
#   lr_cov=5.0e+00, lr_cor=5.0e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=0
#   Results: align=0.858, no_align=0.840, time=5.3s
#
# [Seed 1/5, Exp 2/5] Running:
#   lr_cov=5.0e+00, lr_cor=5.0e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=3, target=0
#   Results: align=0.886, no_align=0.806, time=5.3s
#
# [Seed 1/5, Exp 3/5] Running:
#   lr_cov=5.0e+00, lr_cor=5.0e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=7, target=0
#   Results: align=0.791, no_align=0.697, time=5.3s
#
# [Seed 1/5, Exp 4/5] Running:
#   lr_cov=5.0e+00, lr_cor=5.0e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=8, target=0
#   Results: align=0.838, no_align=0.790, time=5.4s
#
# [Seed 1/5, Exp 5/5] Running:
#   lr_cov=5.0e+00, lr_cor=5.0e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=9, target=0
#   Results: align=0.769, no_align=0.754, time=5.1s
#
# ...
# NTRY Round 2/5, Seed: 7490
# ...
#
# ...

# %%
python /root/SPDSW-main/experiments/scripts/da_transfs_500.py --ntry 5 --task subject

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py  --epho 500 --ntry 5 --lr_cov 2.5 --lr_cor 2.5 --lr_mix 0.5 --power 0.25 --distance lsm --task subject --use_cov_net 1 --use_cor_net 1
# Out:
# ...
# NTRY Round 1/5, Seed: 2473
# ...
#
# [Seed 1/5, Exp 1/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=1
#   Results: align=1.000, no_align=1.000, time=0.0s
#
# [Seed 1/5, Exp 2/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=3
#   Results: align=0.693, no_align=0.478, time=5.7s
#
# [Seed 1/5, Exp 3/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=7
#   Results: align=0.583, no_align=0.487, time=5.3s
#
# [Seed 1/5, Exp 4/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=8
#   Results: align=0.693, no_align=0.417, time=5.3s
#
# [Seed 1/5, Exp 5/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=9
#   Results: align=0.485, no_align=0.274, time=5.0s
#
# [Seed 1/5, Exp 6/25] Running:
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py  --epho 500 --ntry 5 --lr_cov 2.5 --lr_cor 2.5 --lr_mix 0.5 --power 0.25 --distance olm --task subject --use_cov_net 1 --use_cor_net 1
# Out:
# ...
# NTRY Round 1/5, Seed: 2473
# ...
#
# [Seed 1/5, Exp 1/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=1
#   Results: align=1.000, no_align=1.000, time=0.0s
#
# [Seed 1/5, Exp 2/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=3
#   Results: align=0.689, no_align=0.522, time=5.4s
#
# [Seed 1/5, Exp 3/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=7
#   Results: align=0.565, no_align=0.472, time=4.7s
#
# [Seed 1/5, Exp 4/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=8
#   Results: align=0.652, no_align=0.383, time=5.4s
#
# [Seed 1/5, Exp 5/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=9
#   Results: align=0.494, no_align=0.266, time=4.4s
#
# [Seed 1/5, Exp 6/25] Running:
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py  --epho 500 --ntry 5 --lr_cov 2.5 --lr_cor 2.5 --lr_mix 0.5 --power 0.25 --distance ecm --task subject --use_cov_net 1 --use_cor_net 1
# Out:
# ...
# NTRY Round 1/5, Seed: 2473
# ...
#
# [Seed 1/5, Exp 1/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=1
#   Results: align=1.000, no_align=1.000, time=0.0s
#
# [Seed 1/5, Exp 2/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=3
#   Results: align=0.685, no_align=0.507, time=5.4s
#
# [Seed 1/5, Exp 3/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=7
#   Results: align=0.572, no_align=0.476, time=4.6s
#
# [Seed 1/5, Exp 4/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=8
#   Results: align=0.674, no_align=0.386, time=4.6s
#
# [Seed 1/5, Exp 5/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=9
#   Results: align=0.460, no_align=0.266, time=4.5s
#
# [Seed 1/5, Exp 6/25] Running:
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py  --epho 500 --ntry 5 --lr_cov 2.5 --lr_cor 2.5 --lr_mix 0.5 --power 0.25 --distance lecm --task subject --use_cov_net 1 --use_cor_net 1
# Out:
# ...
# NTRY Round 1/5, Seed: 2473
# ...
#
# [Seed 1/5, Exp 1/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=1
#   Results: align=1.000, no_align=1.000, time=0.0s
#
# [Seed 1/5, Exp 2/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=3
#   Results: align=0.696, no_align=0.511, time=5.4s
#
# [Seed 1/5, Exp 3/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=7
#   Results: align=0.572, no_align=0.491, time=4.6s
#
# [Seed 1/5, Exp 4/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=8
#   Results: align=0.678, no_align=0.383, time=4.6s
#
# [Seed 1/5, Exp 5/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=9
#   Results: align=0.443, no_align=0.266, time=4.4s
#
# [Seed 1/5, Exp 6/25] Running:
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py  --epho 500 --ntry 5 --lr_cov 2.5 --lr_cor 2.5 --lr_mix 0.5 --power 0.25 --distance lsm --task subject --use_cov_net 1 --use_cor_net 1
# Out:
# ...
# NTRY Round 1/5, Seed: 2473
# ...
#
# [Seed 1/5, Exp 1/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=1
#   Results: align=1.000, no_align=1.000, time=0.0s
#
# [Seed 1/5, Exp 2/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=3
# Training (lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, subject=1, seed=2473): 100%|██████████| 500/500 [00:04<00:00, 100.10it/s, loss = 0.000, lambda1=0.472, lambda2=0.528]
#   Results: align=0.693, no_align=0.478, time=5.7s
#
# [Seed 1/5, Exp 3/25] Running:
#   lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, seed=2473
#   subject=1, target=7
# Training (lr_cov=2.5e+00, lr_cor=2.5e+00, lr_mix=5.0e-01, power=0.25, subject=1, seed=2473): 100%|██████████| 500/500 [00:05<00:00, 94.27it/s, loss = 0.000, lambda1=0.486, lambda2=0.514]
#   Results: align=0.583, no_align=0.487, time=5.3s
#
# [Seed 1/5, Exp 4/25] Running:
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.75 --power 0.25 --distance lsm --task subject
# molg(x)-phi(corr)
# Out:
# ...
# NTRY Round 1/1, Seed: 7069
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=7.5e-01, power=0.25, seed=7069
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=7.5e-01, power=0.25, seed=7069
#   subject=1, target=3
# Training (lr=7.5e-01, power=0.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 116.63it/s, loss = 0.001]
#   Results: align=0.648, no_align=0.559, time=5.1s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=7.5e-01, power=0.25, seed=7069
#   subject=1, target=7
# Training (lr=7.5e-01, power=0.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 107.73it/s, loss = 0.000]
#   Results: align=0.583, no_align=0.535, time=4.7s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=7.5e-01, power=0.25, seed=7069
#   subject=1, target=8
# Training (lr=7.5e-01, power=0.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:05<00:00, 87.27it/s, loss = 0.003]
#   Results: align=0.545, no_align=0.360, time=5.7s
#
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.5 --power 0.25 --distance lsm --task subject
# molg(x)-phi(corr)
# Out:
# ...
# NTRY Round 1/1, Seed: 7069
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=5.0e-01, power=0.25, seed=7069
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=5.0e-01, power=0.25, seed=7069
#   subject=1, target=3
# Training (lr=5.0e-01, power=0.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 116.20it/s, loss = 0.001]
#   Results: align=0.656, no_align=0.559, time=4.3s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=5.0e-01, power=0.25, seed=7069
#   subject=1, target=7
# Training (lr=5.0e-01, power=0.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:05<00:00, 88.64it/s, loss = 0.000]
#   Results: align=0.583, no_align=0.535, time=5.7s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=5.0e-01, power=0.25, seed=7069
#   subject=1, target=8
# Training (lr=5.0e-01, power=0.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:05<00:00, 87.52it/s, loss = 0.004]
#   Results: align=0.545, no_align=0.360, time=5.7s
#
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.5 --power 0.25 --distance lsm --task subject
# molg(x)-0.1phi(corr)
# Out:
# ...
# NTRY Round 1/1, Seed: 7069
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=5.0e-01, power=0.25, seed=7069
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=5.0e-01, power=0.25, seed=7069
#   subject=1, target=3
# Training (lr=5.0e-01, power=0.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 111.79it/s, loss = 0.001]
#   Results: align=0.700, no_align=0.519, time=4.5s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=5.0e-01, power=0.25, seed=7069
#   subject=1, target=7
# Training (lr=5.0e-01, power=0.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 120.64it/s, loss = 0.000]
#   Results: align=0.572, no_align=0.509, time=4.2s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=5.0e-01, power=0.25, seed=7069
#   subject=1, target=8
# Training (lr=5.0e-01, power=0.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 111.23it/s, loss = 0.002]
#   Results: align=0.606, no_align=0.367, time=4.5s
#
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.75 --power 0.25 --distance lsm --task subject
# molg(x)-0.1phi(corr)
# Out:
# ...
# NTRY Round 1/1, Seed: 7069
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=7.5e-01, power=0.25, seed=7069
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=7.5e-01, power=0.25, seed=7069
#   subject=1, target=3
# Training (lr=7.5e-01, power=0.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 119.26it/s, loss = 0.001]
#   Results: align=0.707, no_align=0.519, time=4.2s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=7.5e-01, power=0.25, seed=7069
#   subject=1, target=7
# Training (lr=7.5e-01, power=0.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:05<00:00, 84.64it/s, loss = 0.000]
#   Results: align=0.587, no_align=0.509, time=5.9s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=7.5e-01, power=0.25, seed=7069
#   subject=1, target=8
# Training (lr=7.5e-01, power=0.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:05<00:00, 96.02it/s, loss = 0.001]
#   Results: align=0.610, no_align=0.367, time=5.2s
#
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.75 --power 0.25 --distance lsm --task subject
# molg(x)-0.1phi(corr)
# Out:
# ...
# NTRY Round 1/1, Seed: 7069
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=7.5e-01, power=0.25, seed=7069
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=7.5e-01, power=0.25, seed=7069
#   subject=1, target=3
# Training (lr=7.5e-01, power=0.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 107.46it/s, loss = 0.000]
#   Results: align=0.581, no_align=0.363, time=5.3s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=7.5e-01, power=0.25, seed=7069
#   subject=1, target=7
# Training (lr=7.5e-01, power=0.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:05<00:00, 89.94it/s, loss = 0.000]
#   Results: align=0.480, no_align=0.399, time=5.6s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=7.5e-01, power=0.25, seed=7069
#   subject=1, target=8
# Training (lr=7.5e-01, power=0.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 110.52it/s, loss = 0.000]
#   Results: align=0.576, no_align=0.443, time=4.5s
#
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 1 --power 0.25 --distance lsm --task subject
# only phi(corr)
# Out:
# ...
# NTRY Round 1/1, Seed: 7069
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=1.0e+00, power=0.25, seed=7069
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=1.0e+00, power=0.25, seed=7069
#   subject=1, target=3
# Training (lr=1.0e+00, power=0.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 101.71it/s, loss = 0.000]
#   Results: align=0.607, no_align=0.363, time=6.0s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=1.0e+00, power=0.25, seed=7069
#   subject=1, target=7
# Training (lr=1.0e+00, power=0.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 102.33it/s, loss = 0.000]
#   Results: align=0.476, no_align=0.399, time=4.9s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=1.0e+00, power=0.25, seed=7069
#   subject=1, target=8
# Training (lr=1.0e+00, power=0.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:05<00:00, 87.24it/s, loss = 0.000]
#   Results: align=0.576, no_align=0.443, time=5.7s
#
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.5 --power 0.25 --distance lsm --task subject
# only phi(corr)
# Out:
# ...
# NTRY Round 1/1, Seed: 7069
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=5.0e-01, power=0.25, seed=7069
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=5.0e-01, power=0.25, seed=7069
#   subject=1, target=3
# Training (lr=5.0e-01, power=0.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:03<00:00, 127.51it/s, loss = 0.000]
#   Results: align=0.567, no_align=0.363, time=4.5s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=5.0e-01, power=0.25, seed=7069
#   subject=1, target=7
# Training (lr=5.0e-01, power=0.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:05<00:00, 96.16it/s, loss = 0.000]
#   Results: align=0.483, no_align=0.399, time=5.2s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=5.0e-01, power=0.25, seed=7069
#   subject=1, target=8
# Training (lr=5.0e-01, power=0.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:05<00:00, 87.98it/s, loss = 0.000]
#   Results: align=0.580, no_align=0.443, time=5.7s
#
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.5 --power 1 --distance olm --task subject
# only phi(corr)
# Out:
# ...
# NTRY Round 1/1, Seed: 7069
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=3
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 113.95it/s, loss = 0.001]
#   Results: align=0.707, no_align=0.567, time=5.1s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=7
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 106.38it/s, loss = 0.000]
#   Results: align=0.561, no_align=0.535, time=4.7s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=8
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:05<00:00, 99.66it/s, loss = 0.001]
#   Results: align=0.602, no_align=0.428, time=5.0s
#
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.5 --power 1 --distance olm --task subject
# 0.1*molg(x)+phi(corr)
# Out:
# ...
# NTRY Round 1/1, Seed: 7069
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=3
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 113.29it/s, loss = 0.001]
#   Results: align=0.563, no_align=0.407, time=5.1s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=7
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 104.58it/s, loss = 0.000]
#   Results: align=0.476, no_align=0.321, time=4.8s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=8
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:05<00:00, 90.66it/s, loss = 0.000]
#   Results: align=0.511, no_align=0.519, time=5.5s
#
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.5 --power 1 --distance olm --task subject
# molg(x)-0.5*phi(corr)
# Out:
#   Results: align=0.715, no_align=0.585, time=5.0s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=7
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:06<00:00, 81.57it/s, loss = 0.000]
#   Results: align=0.565, no_align=0.583, time=6.1s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=8
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:06<00:00, 81.87it/s, loss = 0.002]
#   Results: align=0.598, no_align=0.364, time=6.1s
#
# [Seed 1/1, Exp 5/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=9
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 102.80it/s, loss = 0.006]
#   Results: align=0.350, no_align=0.270, time=4.9s
#
# [Seed 1/1, Exp 6/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=3, target=1
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.5 --power 1 --distance olm --task subject
# molg(x)-0.1*phi(corr)
# Out:
# ...
# NTRY Round 1/1, Seed: 7069
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=3
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 116.24it/s, loss = 0.001]
#   Results: align=0.707, no_align=0.567, time=4.9s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=7
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:05<00:00, 95.35it/s, loss = 0.000]
#   Results: align=0.561, no_align=0.535, time=5.3s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=8
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:05<00:00, 87.78it/s, loss = 0.001]
#   Results: align=0.602, no_align=0.428, time=5.7s
#
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.5 --power 1 --distance lecm --task subject
# molg(x)-0.1*phi(corr)
# Out:
# ...
# NTRY Round 1/1, Seed: 7069
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=3
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 109.68it/s, loss = 0.001]
#   Results: align=0.693, no_align=0.530, time=5.2s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=7
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:05<00:00, 89.45it/s, loss = 0.000]
#   Results: align=0.542, no_align=0.506, time=5.6s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=8
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:05<00:00, 86.03it/s, loss = 0.001]
#   Results: align=0.602, no_align=0.394, time=5.8s
#
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.5 --power 1 --distance ecm --task subject
# molg(x)-0.1*phi(corr)
# Out:
# ...
# NTRY Round 1/1, Seed: 7069
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=3
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 102.00it/s, loss = 0.001]
#   Results: align=0.678, no_align=0.441, time=5.9s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=7
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 105.64it/s, loss = 0.001]

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.5 --power 0.5 --distance lsm --task subject
# molg(x)-0.1*phi(corr)
# Out:
# ...
# NTRY Round 1/1, Seed: 7069
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=5.0e-01, power=0.50, seed=7069
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=5.0e-01, power=0.50, seed=7069
#   subject=1, target=3
# Training (lr=5.0e-01, power=0.50, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 112.71it/s, loss = 0.000]
#   Results: align=0.626, no_align=0.389, time=5.3s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=5.0e-01, power=0.50, seed=7069
#   subject=1, target=7
# Training (lr=5.0e-01, power=0.50, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 104.18it/s, loss = 0.000]
#   Results: align=0.524, no_align=0.413, time=4.8s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=5.0e-01, power=0.50, seed=7069
#   subject=1, target=8
# Training (lr=5.0e-01, power=0.50, subject=1, seed=7069): 100%|██████████| 500/500 [00:05<00:00, 93.17it/s, loss = 0.000]

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.5 --power 1 --distance lsm --task subject
# molg(x)-0.1*phi(corr)

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.5 --power 0.9 --distance lsm --task subject
# molg(x)-0.1*phi(corr)
# Out:
# ...
# NTRY Round 1/1, Seed: 7069
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=5.0e-01, power=0.90, seed=7069
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=5.0e-01, power=0.90, seed=7069
#   subject=1, target=3
# Training (lr=5.0e-01, power=0.90, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 103.16it/s, loss = 0.001]
#   Results: align=0.715, no_align=0.541, time=5.4s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=5.0e-01, power=0.90, seed=7069
#   subject=1, target=7
# Training (lr=5.0e-01, power=0.90, subject=1, seed=7069): 100%|██████████| 500/500 [00:05<00:00, 87.36it/s, loss = 0.000]
#   Results: align=0.576, no_align=0.513, time=5.7s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=5.0e-01, power=0.90, seed=7069
#   subject=1, target=8
# Training (lr=5.0e-01, power=0.90, subject=1, seed=7069): 100%|██████████| 500/500 [00:05<00:00, 87.72it/s, loss = 0.002]
#   Results: align=0.640, no_align=0.420, time=5.7s
#
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.5 --power 1.05 --distance lsm --task subject
# molg(x)-0.1*phi(corr)
# Out:
# ...
# NTRY Round 1/1, Seed: 7069
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=5.0e-01, power=1.05, seed=7069
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=5.0e-01, power=1.05, seed=7069
#   subject=1, target=3
#   Results: align=0.707, no_align=0.541, time=6.2s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=5.0e-01, power=1.05, seed=7069
#   subject=1, target=7
# Training (lr=5.0e-01, power=1.05, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 107.46it/s, loss = 0.000]
#   Results: align=0.576, no_align=0.502, time=5.3s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=5.0e-01, power=1.05, seed=7069
#   subject=1, target=8
# Training (lr=5.0e-01, power=1.05, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 106.19it/s, loss = 0.002]
#   Results: align=0.636, no_align=0.424, time=4.7s
#
# [Seed 1/1, Exp 5/25] Running:
#   lr=5.0e-01, power=1.05, seed=7069
#   subject=1, target=9
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.5 --power 1.25 --distance lsm --task subject
# molg(x)-0.1*phi(corr)
# Out:
# ...
# NTRY Round 1/1, Seed: 7069
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=5.0e-01, power=1.25, seed=7069
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=5.0e-01, power=1.25, seed=7069
#   subject=1, target=3
# Training (lr=5.0e-01, power=1.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 114.03it/s, loss = 0.001]
#   Results: align=0.707, no_align=0.552, time=5.4s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=5.0e-01, power=1.25, seed=7069
#   subject=1, target=7
# Training (lr=5.0e-01, power=1.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 103.96it/s, loss = 0.000]
#   Results: align=0.598, no_align=0.524, time=4.8s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=5.0e-01, power=1.25, seed=7069
#   subject=1, target=8
# Training (lr=5.0e-01, power=1.25, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 120.97it/s, loss = 0.002]
#   Results: align=0.561, no_align=0.436, time=4.1s
#
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.75 --power 1 --distance lsm --task subject
# molg(x)-0.1*phi(corr)
# Out:
# ...
# NTRY Round 1/1, Seed: 7069
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=7.5e-01, power=1.00, seed=7069
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=7.5e-01, power=1.00, seed=7069
#   subject=1, target=3
# Training (lr=7.5e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:03<00:00, 134.53it/s, loss = 0.001]
#   Results: align=0.696, no_align=0.541, time=4.3s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=7.5e-01, power=1.00, seed=7069
#   subject=1, target=7
# Training (lr=7.5e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:05<00:00, 99.56it/s, loss = 0.000]
#   Results: align=0.579, no_align=0.509, time=5.0s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=7.5e-01, power=1.00, seed=7069
#   subject=1, target=8
# Training (lr=7.5e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 105.44it/s, loss = 0.001]
#   Results: align=0.659, no_align=0.424, time=4.8s
#
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.5 --power 1 --distance lsm --task subject
# molg(x)-0.05*phi(corr)
# Out:
# ...
# NTRY Round 1/1, Seed: 7069
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=3
#   Results: align=0.693, no_align=0.548, time=5.6s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=7
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 116.25it/s, loss = 0.000]
#   Results: align=0.583, no_align=0.513, time=4.9s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=8
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 102.12it/s, loss = 0.002]
#   Results: align=0.648, no_align=0.432, time=4.9s
#
# [Seed 1/1, Exp 5/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=9
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.5 --power 1 --distance lsm --task subject
# molg(x)-0.25*phi(corr)
# Out:
# ...
# NTRY Round 1/1, Seed: 7069
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=3
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 109.41it/s, loss = 0.001]
#   Results: align=0.659, no_align=0.556, time=5.2s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=7
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:05<00:00, 97.91it/s, loss = 0.000]
#   Results: align=0.590, no_align=0.531, time=5.1s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=8
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 104.60it/s, loss = 0.004]

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.5 --power 1 --distance lsm --task subject
# molg(x)-0.15*phi(corr)
# Out:
# ...
# NTRY Round 1/1, Seed: 7069
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=3
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:04<00:00, 100.41it/s, loss = 0.001]
#   Results: align=0.693, no_align=0.548, time=5.6s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=5.0e-01, power=1.00, seed=7069
#   subject=1, target=7
# Training (lr=5.0e-01, power=1.00, subject=1, seed=7069): 100%|██████████| 500/500 [00:05<00:00, 85.41it/s, loss = 0.000]

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 5 --lr 1 --power 0.25 --distance lsm --task subject
# Out:
# ...
# NTRY Round 1/5, Seed: 4472
# ...
#
# [Seed 1/5, Exp 1/25] Running:
#   lr=1.0e+00, power=0.25, seed=4472
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/5, Exp 2/25] Running:
#   lr=1.0e+00, power=0.25, seed=4472
#   subject=1, target=3
# Training (lr=1.0e+00, power=0.25, subject=1, seed=4472): 100%|██████████| 500/500 [00:05<00:00, 85.51it/s, loss = 0.029]
#   Results: align=0.667, no_align=0.481, time=7.0s
#
# [Seed 1/5, Exp 3/25] Running:
#   lr=1.0e+00, power=0.25, seed=4472
#   subject=1, target=7
# Training (lr=1.0e+00, power=0.25, subject=1, seed=4472): 100%|██████████| 500/500 [00:05<00:00, 86.58it/s, loss = 0.016]
#   Results: align=0.568, no_align=0.483, time=5.8s
#
# [Seed 1/5, Exp 4/25] Running:
#   lr=1.0e+00, power=0.25, seed=4472
#   subject=1, target=8
# Training (lr=1.0e+00, power=0.25, subject=1, seed=4472): 100%|██████████| 500/500 [00:05<00:00, 88.59it/s, loss = 0.036]
#   Results: align=0.644, no_align=0.405, time=5.7s
#
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 5 --lr 0.75 --power 0.25 --distance olm --task subject
# Out:
# ...
# NTRY Round 1/5, Seed: 4472
# ...
#
# [Seed 1/5, Exp 1/25] Running:
#   lr=7.5e-01, power=0.25, seed=4472
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/5, Exp 2/25] Running:
#   lr=7.5e-01, power=0.25, seed=4472
#   subject=1, target=3
# torch.Size([500, 22, 22])
# Training (lr=7.5e-01, power=0.25, subject=1, seed=4472): 100%|██████████| 500/500 [00:03<00:00, 130.81it/s, loss = 0.011]
#   Results: align=0.696, no_align=0.515, time=4.4s
#
# [Seed 1/5, Exp 3/25] Running:
#   lr=7.5e-01, power=0.25, seed=4472
#   subject=1, target=7
# torch.Size([500, 22, 22])
# Training (lr=7.5e-01, power=0.25, subject=1, seed=4472): 100%|██████████| 500/500 [00:04<00:00, 122.63it/s, loss = 0.001]
#   Results: align=0.590, no_align=0.469, time=4.1s
#
# [Seed 1/5, Exp 4/25] Running:
#   lr=7.5e-01, power=0.25, seed=4472
#   subject=1, target=8
# torch.Size([500, 22, 22])
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 5 --lr 0.5 --power 0.25 --distance olm
# Out:
# ...
# NTRY Round 1/5, Seed: 4472
# ...
#
# [Seed 1/5, Exp 1/5] Running:
#   lr=5.0e-01, power=0.25, seed=4472
#   subject=1, target=0
# torch.Size([500, 22, 22])
# Training (lr=5.0e-01, power=0.25, subject=1, seed=4472): 100%|██████████| 500/500 [00:04<00:00, 121.74it/s, loss = 0.000]
#   Results: align=0.851, no_align=0.851, time=5.2s
#
# [Seed 1/5, Exp 2/5] Running:
#   lr=5.0e-01, power=0.25, seed=4472
#   subject=3, target=0
# torch.Size([500, 22, 22])
# Training (lr=5.0e-01, power=0.25, subject=3, seed=4472): 100%|██████████| 500/500 [00:05<00:00, 87.55it/s, loss = 0.000]
#   Results: align=0.857, no_align=0.806, time=5.7s
#
# [Seed 1/5, Exp 3/5] Running:
#   lr=5.0e-01, power=0.25, seed=4472
#   subject=7, target=0
# torch.Size([500, 22, 22])
# Training (lr=5.0e-01, power=0.25, subject=7, seed=4472): 100%|██████████| 500/500 [00:05<00:00, 86.81it/s, loss = 0.001]
#   Results: align=0.776, no_align=0.693, time=5.8s
#
# [Seed 1/5, Exp 4/5] Running:
#   lr=5.0e-01, power=0.25, seed=4472
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 5 --lr 0.1 --power 0.25 --distance olm
# Out:
# ...
# NTRY Round 1/5, Seed: 4472
# ...
#
# [Seed 1/5, Exp 1/5] Running:
#   lr=1.0e-01, power=0.25, seed=4472
#   subject=1, target=0
# torch.Size([500, 22, 22])
# Training (lr=1.0e-01, power=0.25, subject=1, seed=4472): 100%|██████████| 500/500 [00:03<00:00, 125.94it/s, loss = 0.000]
#   Results: align=0.854, no_align=0.851, time=4.0s
#
# [Seed 1/5, Exp 2/5] Running:
#   lr=1.0e-01, power=0.25, seed=4472
#   subject=3, target=0
# torch.Size([500, 22, 22])
# Training (lr=1.0e-01, power=0.25, subject=3, seed=4472): 100%|██████████| 500/500 [00:05<00:00, 88.66it/s, loss = 0.001]
#   Results: align=0.846, no_align=0.806, time=5.7s
#
# [Seed 1/5, Exp 3/5] Running:
#   lr=1.0e-01, power=0.25, seed=4472
#   subject=7, target=0
# torch.Size([500, 22, 22])
# Training (lr=1.0e-01, power=0.25, subject=7, seed=4472): 100%|██████████| 500/500 [00:04<00:00, 101.87it/s, loss = 0.001]
#   Results: align=0.776, no_align=0.693, time=4.9s
#
# [Seed 1/5, Exp 4/5] Running:
#   lr=1.0e-01, power=0.25, seed=4472
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 5 --lr 0.5 --power 0.25 --distance lsm
# Out:
# ...
# NTRY Round 1/5, Seed: 4472
# ...
#
# [Seed 1/5, Exp 1/5] Running:
#   lr=5.0e-01, power=0.25, seed=4472
#   subject=1, target=0
# torch.Size([500, 22, 22])
# Training (lr=5.0e-01, power=0.25, subject=1, seed=4472): 100%|██████████| 500/500 [00:03<00:00, 135.54it/s, loss = 0.000]
#   Results: align=0.861, no_align=0.843, time=4.7s
#
# [Seed 1/5, Exp 2/5] Running:
#   lr=5.0e-01, power=0.25, seed=4472
#   subject=3, target=0
# torch.Size([500, 22, 22])
# Training (lr=5.0e-01, power=0.25, subject=3, seed=4472): 100%|██████████| 500/500 [00:03<00:00, 138.64it/s, loss = 0.001]
#   Results: align=0.879, no_align=0.824, time=3.6s
#
# [Seed 1/5, Exp 3/5] Running:
#   lr=5.0e-01, power=0.25, seed=4472
#   subject=7, target=0
# torch.Size([500, 22, 22])
# Training (lr=5.0e-01, power=0.25, subject=7, seed=4472): 100%|██████████| 500/500 [00:04<00:00, 105.40it/s, loss = 0.000]
#   Results: align=0.776, no_align=0.632, time=4.8s
#
# [Seed 1/5, Exp 4/5] Running:
#   lr=5.0e-01, power=0.25, seed=4472
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 5 --lr 0.1 --power 0.25 --distance lsm
# Out:
# ...
# NTRY Round 1/5, Seed: 4472
# ...
#
# [Seed 1/5, Exp 1/5] Running:
#   lr=1.0e-01, power=0.25, seed=4472
#   subject=1, target=0
# torch.Size([500, 22, 22])
# Training (lr=1.0e-01, power=0.25, subject=1, seed=4472): 100%|██████████| 500/500 [00:04<00:00, 105.41it/s, loss = 0.000]
#   Results: align=0.858, no_align=0.843, time=4.8s
#
# [Seed 1/5, Exp 2/5] Running:
#   lr=1.0e-01, power=0.25, seed=4472
#   subject=3, target=0
# torch.Size([500, 22, 22])
# Training (lr=1.0e-01, power=0.25, subject=3, seed=4472): 100%|██████████| 500/500 [00:05<00:00, 84.24it/s, loss = 0.001]
#   Results: align=0.835, no_align=0.824, time=5.9s
#
# [Seed 1/5, Exp 3/5] Running:
#   lr=1.0e-01, power=0.25, seed=4472
#   subject=7, target=0
# torch.Size([500, 22, 22])
# Training (lr=1.0e-01, power=0.25, subject=7, seed=4472): 100%|██████████| 500/500 [00:04<00:00, 103.89it/s, loss = 0.001]
#   Results: align=0.783, no_align=0.632, time=4.8s
#
# [Seed 1/5, Exp 4/5] Running:
#   lr=1.0e-01, power=0.25, seed=4472
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --ntry 5 --epho 500 --ntry 5 --lr 0.25 --power 0.25 --distance olm
# Out:
# ...
# NTRY Round 1/5, Seed: 4472
# ...
#
# [Seed 1/5, Exp 1/5] Running:
#   lr=2.5e-01, power=0.25, seed=4472
#   subject=1, target=0
# torch.Size([500, 22, 22])
# Training (lr=2.5e-01, power=0.25, subject=1, seed=4472): 100%|██████████| 500/500 [00:03<00:00, 127.07it/s, loss = 0.000]
#   Results: align=0.858, no_align=0.851, time=4.6s
#
# [Seed 1/5, Exp 2/5] Running:
#   lr=2.5e-01, power=0.25, seed=4472
#   subject=3, target=0
# torch.Size([500, 22, 22])
# Training (lr=2.5e-01, power=0.25, subject=3, seed=4472): 100%|██████████| 500/500 [00:04<00:00, 118.31it/s, loss = 0.001]
#   Results: align=0.861, no_align=0.806, time=4.2s
#
# [Seed 1/5, Exp 3/5] Running:
#   lr=2.5e-01, power=0.25, seed=4472
#   subject=7, target=0
# torch.Size([500, 22, 22])
# Training (lr=2.5e-01, power=0.25, subject=7, seed=4472): 100%|██████████| 500/500 [00:04<00:00, 122.71it/s, loss = 0.001]
#   Results: align=0.794, no_align=0.693, time=4.1s
#
# [Seed 1/5, Exp 4/5] Running:
#   lr=2.5e-01, power=0.25, seed=4472
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --ntry 5 --epho 500 --ntry 5 --lr 0.5 --power 0.25 --distance olm
# Out:
# ...
# NTRY Round 1/5, Seed: 4472
# ...
#
# [Seed 1/5, Exp 1/5] Running:
#   lr=5.0e-01, power=0.25, seed=4472
#   subject=1, target=0
# torch.Size([500, 22, 22])
# Training (lr=5.0e-01, power=0.25, subject=1, seed=4472): 100%|██████████| 500/500 [00:03<00:00, 126.29it/s, loss = 0.000]
#   Results: align=0.851, no_align=0.851, time=4.0s
#
# [Seed 1/5, Exp 2/5] Running:
#   lr=5.0e-01, power=0.25, seed=4472
#   subject=3, target=0
# torch.Size([500, 22, 22])
# Training (lr=5.0e-01, power=0.25, subject=3, seed=4472): 100%|██████████| 500/500 [00:03<00:00, 126.16it/s, loss = 0.000]
#   Results: align=0.857, no_align=0.806, time=4.0s
#
# [Seed 1/5, Exp 3/5] Running:
#   lr=5.0e-01, power=0.25, seed=4472
#   subject=7, target=0
# torch.Size([500, 22, 22])
# Training (lr=5.0e-01, power=0.25, subject=7, seed=4472): 100%|██████████| 500/500 [00:03<00:00, 137.98it/s, loss = 0.001]
#   Results: align=0.776, no_align=0.693, time=3.6s
#
# [Seed 1/5, Exp 4/5] Running:
#   lr=5.0e-01, power=0.25, seed=4472
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --ntry 5 --epho 500 --ntry 5 --lr 0.5 --power 0.25 --distance lsm

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --ntry 5 --epho 500 --ntry 5 --lr 0.05 --power 0.25 --distance olm
# Out:
# ...
# NTRY Round 1/5, Seed: 4472
# ...
#
# [Seed 1/5, Exp 1/5] Running:
#   lr=5.0e-02, power=0.25, seed=4472
#   subject=1, target=0
# torch.Size([500, 22, 22])
# Training (lr=5.0e-02, power=0.25, subject=1, seed=4472): 100%|██████████| 500/500 [00:03<00:00, 125.51it/s, loss = 0.000]
#   Results: align=0.843, no_align=0.851, time=4.0s
#
# [Seed 1/5, Exp 2/5] Running:
#   lr=5.0e-02, power=0.25, seed=4472
#   subject=3, target=0
# torch.Size([500, 22, 22])
# Training (lr=5.0e-02, power=0.25, subject=3, seed=4472): 100%|██████████| 500/500 [00:05<00:00, 96.51it/s, loss = 0.001]
#   Results: align=0.850, no_align=0.806, time=5.2s
#
# [Seed 1/5, Exp 3/5] Running:
#   lr=5.0e-02, power=0.25, seed=4472
#   subject=7, target=0
# torch.Size([500, 22, 22])
# Training (lr=5.0e-02, power=0.25, subject=7, seed=4472): 100%|██████████| 500/500 [00:03<00:00, 139.57it/s, loss = 0.001]
#   Results: align=0.783, no_align=0.693, time=3.6s
#
# [Seed 1/5, Exp 4/5] Running:
#   lr=5.0e-02, power=0.25, seed=4472
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.25 --power 0.25 --task subject --distance olm
# Out:
# ...
# NTRY Round 1/1, Seed: 4474
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=2.5e-01, power=0.20, seed=4474
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=2.5e-01, power=0.20, seed=4474
#   subject=1, target=3
#   Results: align=0.689, no_align=0.511, time=5.9s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=2.5e-01, power=0.20, seed=4474
#   subject=1, target=7
#   Results: align=0.576, no_align=0.465, time=5.7s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=2.5e-01, power=0.20, seed=4474
#   subject=1, target=8
#   Results: align=0.598, no_align=0.386, time=5.8s
#
# [Seed 1/1, Exp 5/25] Running:
#   lr=2.5e-01, power=0.20, seed=4474
#   subject=1, target=9
#   Results: align=0.430, no_align=0.266, time=5.8s
#
# [Seed 1/1, Exp 6/25] Running:
#   lr=2.5e-01, power=0.20, seed=4474
#   subject=3, target=1
# Training (lr=2.5e-01, power=0.20, subject=3, seed=4474): 100%|██████████| 500/500 [00:04<00:00, 100.01it/s, loss = 0.004]
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 5 --lr 0.3 --power 0.25 --task subject --distance olm
# Out:
# ...
# NTRY Round 1/5, Seed: 4472
# ...
#
# [Seed 1/5, Exp 1/25] Running:
#   lr=3.0e-01, power=0.25, seed=4472
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/5, Exp 2/25] Running:
#   lr=3.0e-01, power=0.25, seed=4472
#   subject=1, target=3
# Training (lr=3.0e-01, power=0.25, subject=1, seed=4472): 100%|██████████| 500/500 [00:03<00:00, 139.33it/s, loss = 0.005]
#   Results: align=0.693, no_align=0.515, time=3.6s
#
# [Seed 1/5, Exp 3/25] Running:
#   lr=3.0e-01, power=0.25, seed=4472
#   subject=1, target=7
# Training (lr=3.0e-01, power=0.25, subject=1, seed=4472): 100%|██████████| 500/500 [00:04<00:00, 113.84it/s, loss = 0.002]
#   Results: align=0.546, no_align=0.469, time=4.4s
#
# [Seed 1/5, Exp 4/25] Running:
#   lr=3.0e-01, power=0.25, seed=4472
#   subject=1, target=8
# Training (lr=3.0e-01, power=0.25, subject=1, seed=4472): 100%|██████████| 500/500 [00:05<00:00, 87.96it/s, loss = 0.004]
#   Results: align=0.625, no_align=0.383, time=5.7s
#
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.3 --power 0.25 --task subject --distance lsm
# Out:
# ...
# NTRY Round 1/1, Seed: 4474
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=3.0e-01, power=0.25, seed=4474
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=3.0e-01, power=0.25, seed=4474
#   subject=1, target=3
# Training (lr=3.0e-01, power=0.25, subject=1, seed=4474): 100%|██████████| 500/500 [00:03<00:00, 134.73it/s, loss = 0.004]
#   Results: align=0.674, no_align=0.507, time=3.7s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=3.0e-01, power=0.25, seed=4474
#   subject=1, target=7
# Training (lr=3.0e-01, power=0.25, subject=1, seed=4474): 100%|██████████| 500/500 [00:03<00:00, 126.11it/s, loss = 0.002]
#   Results: align=0.561, no_align=0.472, time=4.0s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=3.0e-01, power=0.25, seed=4474
#   subject=1, target=8
# Training (lr=3.0e-01, power=0.25, subject=1, seed=4474): 100%|██████████| 500/500 [00:03<00:00, 140.51it/s, loss = 0.003]
#   Results: align=0.629, no_align=0.394, time=3.6s
#
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 600 --ntry 1 --lr 0.3 --power 0.25 --task subject --distance olm
# Out:
# ...
# NTRY Round 1/1, Seed: 4474
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=3.0e-01, power=0.25, seed=4474
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=3.0e-01, power=0.25, seed=4474
#   subject=1, target=3
# Training (lr=3.0e-01, power=0.25, subject=1, seed=4474): 100%|██████████| 600/600 [00:04<00:00, 132.26it/s, loss = 0.004]
#   Results: align=0.693, no_align=0.515, time=4.6s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=3.0e-01, power=0.25, seed=4474
#   subject=1, target=7
# Training (lr=3.0e-01, power=0.25, subject=1, seed=4474): 100%|██████████| 600/600 [00:06<00:00, 89.28it/s, loss = 0.002]
#   Results: align=0.550, no_align=0.469, time=6.8s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=3.0e-01, power=0.25, seed=4474
#   subject=1, target=8
# Training (lr=3.0e-01, power=0.25, subject=1, seed=4474): 100%|██████████| 600/600 [00:06<00:00, 88.37it/s, loss = 0.005]
#   Results: align=0.598, no_align=0.383, time=6.8s
#
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.25 --power 0.25 --task subject --distance lsm
# Out:
# ...
# NTRY Round 1/1, Seed: 4474
# ...
#
# [Seed 1/1, Exp 1/25] Running:
#   lr=2.5e-01, power=0.10, seed=4474
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/1, Exp 2/25] Running:
#   lr=2.5e-01, power=0.10, seed=4474
#   subject=1, target=3
# Training (lr=2.5e-01, power=0.10, subject=1, seed=4474): 100%|██████████| 500/500 [00:05<00:00, 87.76it/s, loss = 0.004]
#   Results: align=0.696, no_align=0.519, time=5.7s
#
# [Seed 1/1, Exp 3/25] Running:
#   lr=2.5e-01, power=0.10, seed=4474
#   subject=1, target=7
# Training (lr=2.5e-01, power=0.10, subject=1, seed=4474): 100%|██████████| 500/500 [00:05<00:00, 85.68it/s, loss = 0.002]
#   Results: align=0.554, no_align=0.491, time=5.9s
#
# [Seed 1/1, Exp 4/25] Running:
#   lr=2.5e-01, power=0.10, seed=4474
#   subject=1, target=8
# Training (lr=2.5e-01, power=0.10, subject=1, seed=4474): 100%|██████████| 500/500 [00:04<00:00, 107.35it/s, loss = 0.004]
#   Results: align=0.614, no_align=0.386, time=4.7s
#
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 1 --lr 0.25 --power 0.1 --task subject --distance olm
# Out:
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 1, 'multifreq': False, 'reg': 10.0, 'power': 1.5, 'lr': 0.05, 'cross_subject': False}
# 100%|██████████| 500/500 [00:05<00:00, 87.82it/s, loss = 0.003]
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 3, 'multifreq': False, 'reg': 10.0, 'power': 1.5, 'lr': 0.05, 'cross_subject': False}
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 7, 'multifreq': False, 'reg': 10.0, 'power': 1.5, 'lr': 0.05, 'cross_subject': False}
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 8, 'multifreq': False, 'reg': 10.0, 'power': 1.5, 'lr': 0.05, 'cross_subject': False}
# ...

# %%
# %run /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_var.py --epho 500 --ntry 5 --lr 0.25 --power 0.25 --task subject --distance lsm
# Out:
# ...
# NTRY Round 1/5, Seed: 4472
# ...
#
# [Seed 1/5, Exp 1/25] Running:
#   lr=2.5e-01, power=0.25, seed=4472
#   subject=1, target=1
#   Error: too many values to unpack (expected 3)
#
# [Seed 1/5, Exp 2/25] Running:
#   lr=2.5e-01, power=0.25, seed=4472
#   subject=1, target=3
#   Results: align=0.678, no_align=0.507, time=3.5s
#
# [Seed 1/5, Exp 3/25] Running:
#   lr=2.5e-01, power=0.25, seed=4472
#   subject=1, target=7
#   Results: align=0.542, no_align=0.472, time=3.6s
#
# [Seed 1/5, Exp 4/25] Running:
#   lr=2.5e-01, power=0.25, seed=4472
#   subject=1, target=8
#   Results: align=0.655, no_align=0.394, time=3.7s
#
# [Seed 1/5, Exp 5/25] Running:
#   lr=2.5e-01, power=0.25, seed=4472
#   subject=1, target=9
#   Results: align=0.502, no_align=0.266, time=3.6s
#
# [Seed 1/5, Exp 6/25] Running:
#   lr=2.5e-01, power=0.25, seed=4472
#   subject=3, target=1
#   Results: align=0.681, no_align=0.322, time=3.7s
#
# [Seed 1/5, Exp 7/25] Running:
#   lr=2.5e-01, power=0.25, seed=4472
# ...

# %%
# %run da_transfs_changeall_Rd_matrix_log.py  --ntry 3 --task session --lr 5e-3 --power 0.75
# Out:
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 1, 'multifreq': False, 'reg': 10.0, 'power': 0.75, 'lr': 0.005, 'cross_subject': False}
# 100%|██████████| 500/500 [00:05<00:00, 86.99it/s, loss = 0.001]
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 3, 'multifreq': False, 'reg': 10.0, 'power': 0.75, 'lr': 0.005, 'cross_subject': False}
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 7, 'multifreq': False, 'reg': 10.0, 'power': 0.75, 'lr': 0.005, 'cross_subject': False}
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 8, 'multifreq': False, 'reg': 10.0, 'power': 0.75, 'lr': 0.005, 'cross_subject': False}
# ...

# %%
# %run da_transfs_changeall_Rd_matrix_log.py  --ntry 3 --task session --lr 5e-3 --power 0.5
# Out:
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 1, 'multifreq': False, 'reg': 10.0, 'power': 0.5, 'lr': 0.005, 'cross_subject': False}
# 100%|██████████| 500/500 [00:05<00:00, 90.17it/s, loss = 0.000]
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 3, 'multifreq': False, 'reg': 10.0, 'power': 0.5, 'lr': 0.005, 'cross_subject': False}
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 7, 'multifreq': False, 'reg': 10.0, 'power': 0.5, 'lr': 0.005, 'cross_subject': False}
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 8, 'multifreq': False, 'reg': 10.0, 'power': 0.5, 'lr': 0.005, 'cross_subject': False}
# ...

# %%
# %run da_transfs_changeall_Rd_matrix_log.py  --ntry 3 --task session --lr 5e-3 --power 0.25
# Out:
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 1, 'multifreq': False, 'reg': 10.0, 'power': 0.25, 'lr': 0.005, 'cross_subject': False}
# 100%|██████████| 500/500 [00:05<00:00, 86.50it/s, loss = 0.000]
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 3, 'multifreq': False, 'reg': 10.0, 'power': 0.25, 'lr': 0.005, 'cross_subject': False}
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 7, 'multifreq': False, 'reg': 10.0, 'power': 0.25, 'lr': 0.005, 'cross_subject': False}
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 8, 'multifreq': False, 'reg': 10.0, 'power': 0.25, 'lr': 0.005, 'cross_subject': False}
# ...

# %%
# %run da_transfs_changeall_Rd_matrix_log.py  --ntry 3 --task session --lr 5e-3 --power 0.2
# Out:
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 1, 'multifreq': False, 'reg': 10.0, 'power': 0.2, 'lr': 0.005, 'cross_subject': False}
# 100%|██████████| 500/500 [00:05<00:00, 84.36it/s, loss = 0.000]
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 3, 'multifreq': False, 'reg': 10.0, 'power': 0.2, 'lr': 0.005, 'cross_subject': False}
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 7, 'multifreq': False, 'reg': 10.0, 'power': 0.2, 'lr': 0.005, 'cross_subject': False}
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 8, 'multifreq': False, 'reg': 10.0, 'power': 0.2, 'lr': 0.005, 'cross_subject': False}
# ...

# %%
# %run da_transfs_changeall_Rd_matrix_log.py  --ntry 3 --task session --lr 5e-3 --power 0.9
# Out:
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 1, 'multifreq': False, 'reg': 10.0, 'power': 0.9, 'lr': 0.005, 'cross_subject': False}
# 100%|██████████| 500/500 [00:05<00:00, 86.84it/s, loss = 0.001]
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 3, 'multifreq': False, 'reg': 10.0, 'power': 0.9, 'lr': 0.005, 'cross_subject': False}
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 7, 'multifreq': False, 'reg': 10.0, 'power': 0.9, 'lr': 0.005, 'cross_subject': False}
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 8, 'multifreq': False, 'reg': 10.0, 'power': 0.9, 'lr': 0.005, 'cross_subject': False}
# ...

# %%
# %run da_transfs_changeall_Rd_matrix_log.py  --ntry 3 --task session --lr 5e-3 --power 1.5
# Out:
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 1, 'multifreq': False, 'reg': 10.0, 'power': 1.5, 'lr': 0.005, 'cross_subject': False}
# 100%|██████████| 500/500 [00:05<00:00, 89.28it/s, loss = 0.003]
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 3, 'multifreq': False, 'reg': 10.0, 'power': 1.5, 'lr': 0.005, 'cross_subject': False}
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 7, 'multifreq': False, 'reg': 10.0, 'power': 1.5, 'lr': 0.005, 'cross_subject': False}
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 8, 'multifreq': False, 'reg': 10.0, 'power': 1.5, 'lr': 0.005, 'cross_subject': False}
# ...

# %%
# %run da_transfs_changeall_Rd_matrix_log.py  --ntry 3 --task session --lr 5e-3 --power 1.25
# Out:
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 1, 'multifreq': False, 'reg': 10.0, 'power': 1.25, 'lr': 0.005, 'cross_subject': False}
# 100%|██████████| 500/500 [00:05<00:00, 87.57it/s, loss = 0.002]
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 3, 'multifreq': False, 'reg': 10.0, 'power': 1.25, 'lr': 0.005, 'cross_subject': False}
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 7, 'multifreq': False, 'reg': 10.0, 'power': 1.25, 'lr': 0.005, 'cross_subject': False}
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 8, 'multifreq': False, 'reg': 10.0, 'power': 1.25, 'lr': 0.005, 'cross_subject': False}
# ...
