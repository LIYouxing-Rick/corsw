# %%
# %cd /root/SPDSW-main/experiments/scripts/
# Out:
# /root/SPDSW-main/experiments/scripts

# %%
# !bash run_all.sh
# Out:
# {'distance': 'les', 'n_proj': 1000, 'n_epochs': 50, 'seed': np.int64(2473), 'subject': 1, 'target_subject': 1, 'multifreq': False, 'reg': 10.0, 'cross_subject': True}
# {'distance': 'les', 'n_proj': 1000, 'n_epochs': 50, 'seed': np.int64(2473), 'subject': 1, 'target_subject': 3, 'multifreq': False, 'reg': 10.0, 'cross_subject': True}
# {'distance': 'les', 'n_proj': 1000, 'n_epochs': 50, 'seed': np.int64(2473), 'subject': 1, 'target_subject': 7, 'multifreq': False, 'reg': 10.0, 'cross_subject': True}
# {'distance': 'les', 'n_proj': 1000, 'n_epochs': 50, 'seed': np.int64(2473), 'subject': 1, 'target_subject': 8, 'multifreq': False, 'reg': 10.0, 'cross_subject': True}
# {'distance': 'les', 'n_proj': 1000, 'n_epochs': 50, 'seed': np.int64(2473), 'subject': 1, 'target_subject': 9, 'multifreq': False, 'reg': 10.0, 'cross_subject': True}
# ...

# %%
# %run /root/SPDSW-main/experiments/scripts/da_transfs_500.py --ntry 5 --task subject
# Out:
# {'distance': 'spdsw', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2473), 'subject': 1, 'target_subject': 1, 'multifreq': False, 'reg': 10.0, 'cross_subject': True}
# {'distance': 'spdsw', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2473), 'subject': 1, 'target_subject': 3, 'multifreq': False, 'reg': 10.0, 'cross_subject': True}
# {'distance': 'spdsw', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2473), 'subject': 1, 'target_subject': 7, 'multifreq': False, 'reg': 10.0, 'cross_subject': True}
# {'distance': 'spdsw', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2473), 'subject': 1, 'target_subject': 8, 'multifreq': False, 'reg': 10.0, 'cross_subject': True}
# {'distance': 'spdsw', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2473), 'subject': 1, 'target_subject': 9, 'multifreq': False, 'reg': 10.0, 'cross_subject': True}
# ...
