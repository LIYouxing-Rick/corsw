# %%
# %cd /root/corsw_mat/experiments/scripts/
# Out:
# /root/corsw_mat/experiments/scripts

# %%
# %run da_transfs_changeall_Rd_matrix_log.py  --ntry 3 --task session --lr 5e-2 --power 0.5
# Out:
# /root/corsw_mat/experiments/scripts/da_transfs_changeall_Rd_matrix_log.py:371: SyntaxWarning: invalid escape sequence '\p'
#   run_name = f"李群同态_{distance_tag}_p={power_tag}_lr={lr_tag}_epho{step_epoch}_采样\phi_*,o"
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 1, 'multifreq': False, 'reg': 10.0, 'power': 0.5, 'lr': 0.05, 'cross_subject': False}
# 100%|██████████| 500/500 [00:05<00:00, 89.21it/s, loss = 0.000]
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 3, 'multifreq': False, 'reg': 10.0, 'power': 0.5, 'lr': 0.05, 'cross_subject': False}
# {'distance': 'lsm', 'n_proj': 500, 'n_epochs': 500, 'seed': np.int64(2474), 'subject': 1, 'target_subject': 7, 'multifreq': False, 'reg': 10.0, 'power': 0.5, 'lr': 0.05, 'cross_subject': False}
# ...

# %%
# %run da_transfs_changeall_Rd_matrix_log.py  --ntry 3 --task session --lr 5e-2 --power 0.25

# %%
# %run da_transfs_changeall_Rd_matrix_log.py  --ntry 3 --task session --lr 5e-2 --power 0.1

# %%
# %run da_transfs_changeall_Rd_matrix_log.py  --ntry 3 --task session --lr 5e-2 --power 0.9

# %%
# %run da_transfs_changeall_Rd_matrix_log.py  --ntry 3 --task session --lr 5e-2 --power 1.25

# %%
# %run da_transfs_changeall_Rd_matrix_log.py  --ntry 3 --task session --lr 5e-2 --power 1.5

# %%
# %run da_transfs_changeall_Rd_matrix_log.py  --ntry 3 --task session --lr 5e-2 --power 0.75

# %%
# %run da_transfs_changeall_Rd_matrix_log.py  --ntry 3 --task session --lr 5e-3 --power 0.75
